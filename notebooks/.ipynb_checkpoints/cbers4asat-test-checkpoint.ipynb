# %%
# Importar biblioteca do cbers4asat
from cbers4asat import Cbers4aAPI

# A classe date é utilizada para padronizar o formato de data na biblioteca
from datetime import date

# Instanciando o objeto com o usuário cadastrado na plataforma
api = Cbers4aAPI('gabriel.lucas.oceano@gmail.com')

# Bouding Box escolhido
#   O bounding box é formado por 4 coordenadas: [x_min, y_min, x_max, y_max],
#   correspondendo respectivamente a: [oeste, sul, leste, norte].
#   Sendo essa ordem um fator importante para o funcionamento da busca
bbox = [-63.92944335937501, # Oeste
        -8.819260401678381, # Sul
        -63.79211425781251, # Leste
        -8.722218306198739] # Norte

# Intervalo de data para a busca
data_inicial = date(2021, 8, 25)
data_final = date(2021, 9, 25)

# %%
# Fazer uma busca no catálogo e exibir resultados
produtos = api.query(location=bbox,
                     initial_date=data_inicial,
                     end_date=data_final,
                     cloud=100,
                     limit=100,
                     collections=['AMAZONIA1_WFI_L2_DN', 'CBERS4A_WPM_L4_DN']) # Explicação sobre as coleções nos próximos itens abaixo.

print(produtos)
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'id': 'AMAZONIA1_WFI03901620210911CB11', ...
# Out:
# {'type': 'FeatureCollection', 'features': [{'stac_version': '0.9.0', 'stac_extensions': ['eo', 'query'], 'type': 'Feature', 'id': 'AMAZONIA1_WFI03901620210911CB11', 'collection': 'AMAZONIA1_WFI_L2_DN', 'geometry': {'type': 'Polygon', 'coordinates': [[[-70.4307, -1.81375], [-70.4307, -9.96131], [-61.1183, -9.96131], [-61.1183, -1.81375], [-70.4307, -1.81375]]]}, 'bbox': [-70.4307, -9.96131, -61.1183, -1.81375], 'properties': {'datetime': '2021-09-11T14:51:18', 'path': 39, 'row': 16, 'satellite': 'AMAZONIA1', 'sensor': 'WFI', 'cloud_cover': 80.0, 'sync_loss': None, 'eo:gsd': -1, 'eo:bands': [{'name': 'blue', 'common_name': 'blue'}, {'name': 'green', 'common_name': 'green'}, {'name': 'red', 'common_name': 'red'}, {'name': 'nir', 'common_name': 'nir'}]}, 'assets': {'thumbnail': {'href': 'https://www.dgi.inpe.br/datastore/TIFF/AMAZONIA1/2021_09/AMAZONIA_1_WFI_DRD_2021_09_11.14_47_30_CB11/039_016_0/2_BC_LCC_WGS84/AMAZONIA_1_WFI_20210911_039_016.png', 'type': 'image/png'}}, 'links': [{'href': 'https://www.dgi.inpe.br/lgi-stac/collections/AMAZONIA1_WFI_L2_DN/items/AMAZONIA1_WFI03901620210911CB11', 'rel': 'self'}, {'href': 'https://www.dgi.inpe.br/lgi-stac/collections/AMAZONIA1_WFI_L2_DN', 'rel': 'parent'}, {'href': 'https://www.dgi.inpe.br/lgi-stac/collections/AMAZONIA1_WFI_L2_DN', 'rel': 'collection'}, {'href': 'https://www.dgi.inpe.br/lgi-stac/stac', 'rel': 'root'}]}, {'stac_version': '0.9.0', 'stac_extensions': ['eo', 'query'], 'type': 'Feature', 'id': 'AMAZONIA1_WFI03901720210827CB11', 'collection': 'AMAZONIA1_WFI_L2_DN', 'geometry': {'type': 'Polygon', 'coordinates': [[[-71.8437, -7.72848], [-71.8437, -15.9957], [-62.2147, -15.9957], [-62.2147, -7.72848], [-71.8437, -7.72848]]]}, 'bbox': [-71.8437, -15.9957, -62.2147, -7.72848], 'properties': {'datetime': '2021-08-27T14:52:27', 'path': 39, 'row': 17, 'satellite': 'AMAZONIA1', 'sensor': 'WFI', 'cloud_cover': 80.0, 'sync_loss': None, 'eo:gsd': -1, 'eo:bands': [{'name': 'blue', 'common_name': 'blue'}, {'name': 'green', 'common_name': 'green'}, {'name': 'red', 'common_name': 'red'}, {'name': 'nir', 'common_name': 'nir'}]}, 'assets': {'thumbnail': {'href': 'https://www.dgi.inpe.br/datastore/TIFF/AMAZONIA1/2021_08/AMAZONIA_1_WFI_DRD_2021_08_27.14_47_00_CB11/039_017_0/2_BC_LCC_WGS84/AMAZONIA_1_WFI_20210827_039_017.png', 'type': 'image/png'}}, 'links': [{'href': 'https://www.dgi.inpe.br/lgi-stac/collections/AMAZONIA1_WFI_L2_DN/items/AMAZONIA1_WFI03901720210827CB11', 'rel': 'self'}, {'href': 'https://www.dgi.inpe.br/lgi-stac/collections/AMAZONIA1_WFI_L2_DN', 'rel': 'parent'}, {'href': 'https://www.dgi.inpe.br/lgi-stac/collections/AMAZONIA1_WFI_L2_DN', 'rel': 'collection'}, {'href': 'https://www.dgi.inpe.br/lgi-stac/stac', 'rel': 'root'}]}, {'stac_version': '0.9.0', 'stac_extensions': ['eo', 'query'], 'type': 'Feature', 'id': 'CBERS4A_WPM22812420210904', 'collection': 'CBERS4A_WPM_L4_DN', 'geometry': {'type': 'Polygon', 'coordinates': [[[-64.0116, -8.22693], [-64.0116, -9.27461], [-62.9867, -9.27461], [-62.9867, -8.22693], [-64.0116, -8.22693]]]}, 'bbox': [-64.0116, -9.27461, -62.9867, -8.22693], 'properties': {'datetime': '2021-09-04T14:56:12', 'path': 228, 'row': 124, 'satellite': 'CBERS4A', 'sensor': 'WPM', 'cloud_cover': 10.0, 'sync_loss': None, 'eo:gsd': -1, 'eo:bands': [{'name': 'pan', 'common_name': 'pan'}, {'name': 'blue', 'common_name': 'blue'}, {'name': 'green', 'common_name': 'green'}, {'name': 'red', 'common_name': 'red'}, {'name': 'nir', 'common_name': 'nir'}]}, 'assets': {'thumbnail': {'href': 'https://www.dgi.inpe.br/datastore/TIFF/CBERS4A/2021_09/CBERS_4A_WPM_RAW_2021_09_04.14_51_30_ETC2/228_124_0/4_BC_UTM_WGS84/CBERS_4A_WPM_20210904_228_124.png', 'type': 'image/png'}}, 'links': [{'href': 'https://www.dgi.inpe.br/lgi-stac/collections/CBERS4A_WPM_L4_DN/items/CBERS4A_WPM22812420210904', 'rel': 'self'}, {'href': 'https://www.dgi.inpe.br/lgi-stac/collections/CBERS4A_WPM_L4_DN', 'rel': 'parent'}, {'href': 'https://www.dgi.inpe.br/lgi-stac/collections/CBERS4A_WPM_L4_DN', 'rel': ' ...

# %%
gdf = api.to_geodataframe(produtos)

# %%
gdf
# Out:
#                                                                           geometry  \
# id
# AMAZONIA1_WFI03901620210911CB11  POLYGON ((-70.4307 -1.81375, -70.4307 -9.96131...
# AMAZONIA1_WFI03901720210827CB11  POLYGON ((-71.8437 -7.72848, -71.8437 -15.9957...
# CBERS4A_WPM22812420210904        POLYGON ((-64.0116 -8.22693, -64.0116 -9.27461...
# CBERS4A_WPM22912420210830        POLYGON ((-64.7888 -8.22688, -64.7888 -9.27521...
#
#                                             datetime  path  row  satellite  \
# id
# AMAZONIA1_WFI03901620210911CB11  2021-09-11T14:51:18    39   16  AMAZONIA1
# AMAZONIA1_WFI03901720210827CB11  2021-08-27T14:52:27    39   17  AMAZONIA1
# CBERS4A_WPM22812420210904        2021-09-04T14:56:12   228  124    CBERS4A
# CBERS4A_WPM22912420210830        2021-08-30T14:59:15   229  124    CBERS4A
#
#                                 sensor  cloud_cover  \
# id
# AMAZONIA1_WFI03901620210911CB11    WFI         80.0
# AMAZONIA1_WFI03901720210827CB11    WFI         80.0
# CBERS4A_WPM22812420210904          WPM         10.0
# CBERS4A_WPM22912420210830          WPM         60.0
#
#                                                               id  \
# id
# AMAZONIA1_WFI03901620210911CB11  AMAZONIA1_WFI03901620210911CB11
# AMAZONIA1_WFI03901720210827CB11  AMAZONIA1_WFI03901720210827CB11
# CBERS4A_WPM22812420210904              CBERS4A_WPM22812420210904
# CBERS4A_WPM22912420210830              CBERS4A_WPM22912420210830
#
#                                                                      bbox  \
# id
# AMAZONIA1_WFI03901620210911CB11  [-70.4307, -9.96131, -61.1183, -1.81375]
# AMAZONIA1_WFI03901720210827CB11  [-71.8437, -15.9957, -62.2147, -7.72848]
# CBERS4A_WPM22812420210904        [-64.0116, -9.27461, -62.9867, -8.22693]
# CBERS4A_WPM22912420210830        [-64.7888, -9.27521, -63.7633, -8.22688]
#
#                                           collection  \
# id
# AMAZONIA1_WFI03901620210911CB11  AMAZONIA1_WFI_L2_DN
# AMAZONIA1_WFI03901720210827CB11  AMAZONIA1_WFI_L2_DN
# CBERS4A_WPM22812420210904          CBERS4A_WPM_L4_DN
# CBERS4A_WPM22912420210830          CBERS4A_WPM_L4_DN
#
#                                                                          thumbnail
# id
# AMAZONIA1_WFI03901620210911CB11  https://www.dgi.inpe.br/datastore/TIFF/AMAZONI...
# AMAZONIA1_WFI03901720210827CB11  https://www.dgi.inpe.br/datastore/TIFF/AMAZONI...
# CBERS4A_WPM22812420210904        https://www.dgi.inpe.br/datastore/TIFF/CBERS4A...
# CBERS4A_WPM22912420210830        https://www.dgi.inpe.br/datastore/TIFF/CBERS4A...
